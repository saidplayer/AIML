# %% [markdown]
# # Testing and optimizing agents

# %% [markdown]
# ## Practice activity: Designing test cases for ML systems

# %%
# !pip install pytest
# !Pip install ipytest

# %%
def checker(f):  
    """Measures execution time."""  
    def wrap(*args, **kwargs):  
        print("Before")  # Pre-execution message  
        f(*args, **kwargs)  
        print("Before")  # Pre-execution message  
    return wrap

# %%
import ipytest
import pytest
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
import numpy as np

# Load the dataset
iris = load_iris()
X, y = iris.data, iris.target

# Set up the model
model = DecisionTreeClassifier()
model.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
def predict_model(*args, **kwargs):
    return model.predict(*args, **kwargs)

model.predict = predict_model

# %%
def test_typical_case():
    input_data = np.array([[4.5, 2.3, 1.3, 0.3]])  # Example input for a flower classification model
    expected_output = 0  # Expected output for typical case (Setosa class index)
    result = model.predict(input_data)[0]
    assert result == expected_output, f"Expected {expected_output}, but got {result}"

# %%
test_typical_case()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 test_typical_case()
#
# Cell In[51], line 4, in test_typical_case()
#       2 input_data = np.array([[4.5, 2.3, 1.3, 0.3]])  # Example input for a flower classification model
#       3 expected_output = 0  # Expected output for typical case (Setosa class index)
# ----> 4 result = model.predict(input_data)[0]
#       5 assert result == expected_output, f"Expected {expected_output}, but got {result}"
#
# Cell In[50], line 2, in predict_model(*args, **kwargs)
#       1 def predict_model(*args, **kwargs):
# ----> 2     return model.predict(*args, **kwargs)
#
# Cell In[50], line 2, in predict_model(*args, **kwargs)
#       1 def predict_model(*args, **kwargs):
# ----> 2     return model.predict(*args, **kwargs)
#
#     [... skipping similar frames: predict_model at line 2 (2973 times)]
#
# Cell In[50], line 2, in predict_model(*args, **kwargs)
#       1 def predict_model(*args, **kwargs):
# ----> 2     return model.predict(*args, **kwargs)
#
# RecursionError: maximum recursion depth exceeded
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\IPython\core\async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\IPython\core\interactiveshell.py:3386, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3382 exec_count = self.execution_count
#    3383 if result.error_in_exec:
#    3384     # Store formatted traceback and error details
#    3385     self.history_manager.exceptions[exec_count] = (
# -> 3386         self._format_exception_for_storage(result.error_in_exec)
#    3387     )
#    3389 # Each cell is a *single* input, regardless of how many lines it has
#    3390 self.execution_count += 1
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\IPython\core\interactiveshell.py:3440, in InteractiveShell._format_exception_for_storage(self, exception, filename, running_compiled_code)
#    3437         stb = evalue._render_traceback_()
#    3438     else:
#    3439         # Otherwise, use InteractiveTB to format the traceback.
# -> 3440         stb = self.InteractiveTB.structured_traceback(
#    3441             etype, evalue, tb, tb_offset=1
#    3442         )
#    3443 except Exception:
#    3444     # In case formatting fails, fallback to Python's built-in formatting.
#    3445     stb = traceback.format_exception(etype, evalue, tb)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\IPython\core\ultratb.py:1182, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1180 else:
#    1181     self.tb = etb
# -> 1182 return FormattedTB.structured_traceback(
#    1183     self, etype, evalue, etb, tb_offset, context
#    1184 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\IPython\core\ultratb.py:1053, in FormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1050 mode = self.mode
#    1051 if mode in self.verbose_modes:
#    1052     # Verbose modes need a full traceback
# -> 1053     return VerboseTB.structured_traceback(
#    1054         self, etype, evalue, etb, tb_offset, context
#    1055     )
#    1056 elif mode == "Docs":
#    1057     # return DocTB
#    1058     return DocTB(
#    1059         theme_name=self._theme_name,
#    1060         call_pdb=self.call_pdb,
#    (...)   1068         etype, evalue, etb, tb_offset, 1
#    1069     )  # type: ignore[arg-type]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\IPython\core\ultratb.py:861, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     852 def structured_traceback(
#     853     self,
#     854     etype: type,
#    (...)    858     context: int = 5,
#     859 ) -> list[str]:
#     860     """Return a nice text document describing the traceback."""
# --> 861     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#     862         etype, evalue, etb, context, tb_offset
#     863     )
#     865     termsize = min(75, get_terminal_size()[0])
#     866     theme = theme_table[self._theme_name]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\IPython\core\ultratb.py:746, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, context, tb_offset)
#     744 assert isinstance(tb_offset, int)
#     745 head = self.prepare_header(str(etype), self.long_header)
# --> 746 records = self.get_records(etb, context, tb_offset) if etb else []
#     748 frames = []
#     749 skipped = 0
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\IPython\core\ultratb.py:830, in VerboseTB.get_records(self, etb, context, tb_offset)
#     828 except OSError:
#     829     max_len = 0
# --> 830 max_len = max(max_len, max_len)
#     831 tbs.append(cf)
#     832 cf = getattr(cf, "tb_next", None)
#
# KeyboardInterrupt:

# %%
def test_edge_case_extreme_values():
    input_data = np.array([[1000, 1000, 1000, 1000]])  # Extreme values for flower classification
    try:
        model.predict(input_data)
    except ValueError:
        assert True  # The model should raise a ValueError for extreme inputs
    else:
        assert False, "Expected ValueError for extreme values, but no error was raised"

# %%
def test_error_handling_missing_values():
    input_data = np.array([[None, None, None, None]])  # Missing values in input
    try:
        model.predict(input_data)
    except ValueError:
        assert True  # The model should raise a ValueError for missing inputs
    else:
        assert False, "Expected ValueError for missing values, but no error was raised"

# %%
# Run tests using ipytest
ipytest.run('-v')
# Out:
# ======================================= test session starts =======================================
# platform win32 -- Python 3.13.7, pytest-8.4.2, pluggy-1.6.0 -- C:\Users\Shahram\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe
# cachedir: .pytest_cache
# rootdir: g:\Downloads\Organised\Video\Online Courses\Microsoft AI ML\Building Intelligent Troubleshooting Agents
# collecting ... collected 3 items
#
# t_76afb62dd1e94f36929c977f3791daa6.py::test_typical_case FAILED                              [ 33%]
# t_76afb62dd1e94f36929c977f3791daa6.py::test_error_handling_missing_values FAILED             [ 66%]
# t_76afb62dd1e94f36929c977f3791daa6.py::test_edge_case_extreme_values FAILED                  [100%]
#
# ============================================ FAILURES =============================================
# ________________________________________ test_typical_case ________________________________________
#
#     def test_typical_case():
#         input_data = np.array([[4.5, 2.3, 1.3, 0.3]])  # Example input for a flower classification model
#         expected_output = 0  # Expected output for typical case (Setosa class index)
# >       result = model.predict(input_data)[0]
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#
# C:\Users\Shahram\AppData\Local\Temp\ipykernel_3068\710492446.py:4:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# C:\Users\Shahram\AppData\Local\Temp\ipykernel_3068\1005664956.py:5: in wrap
#     f(*args, **kwargs)
# C:\Users\Shahram\AppData\Local\Temp\ipykernel_3068\2857049849.py:3: in predict_model
#     return model.predict(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# C:\Users\Shahram\AppData\Local\Temp\ipykernel_3068\1005664956.py:5: in wrap
#     f(*args, **kwargs)
# E   RecursionError: maximum recursion depth exceeded
# !!! Recursion detected (same locals & position)
# -------------------------------------- Captured stdout call ---------------------------------------
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# _______________________________ test_error_handling_missing_values ________________________________
#
#     def test_error_handling_missing_values():
#         input_data = np.array([[None, None, None, None]])  # Missing values in input
#         try:
# >           model.predict(input_data)
#
# C:\Users\Shahram\AppData\Local\Temp\ipykernel_3068\3084191689.py:4:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# C:\Users\Shahram\AppData\Local\Temp\ipykernel_3068\1005664956.py:5: in wrap
#     f(*args, **kwargs)
# C:\Users\Shahram\AppData\Local\Temp\ipykernel_3068\2857049849.py:3: in predict_model
#     return model.predict(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# C:\Users\Shahram\AppData\Local\Temp\ipykernel_3068\1005664956.py:5: in wrap
#     f(*args, **kwargs)
# E   RecursionError: maximum recursion depth exceeded
# !!! Recursion detected (same locals & position)
# -------------------------------------- Captured stdout call ---------------------------------------
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# __________________________________ test_edge_case_extreme_values __________________________________
#
#     def test_edge_case_extreme_values():
#         input_data = np.array([[1000, 1000, 1000, 1000]])  # Extreme values for flower classification
#         try:
# >           model.predict(input_data)
#
# C:\Users\Shahram\AppData\Local\Temp\ipykernel_3068\1734168487.py:4:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# C:\Users\Shahram\AppData\Local\Temp\ipykernel_3068\1005664956.py:5: in wrap
#     f(*args, **kwargs)
# C:\Users\Shahram\AppData\Local\Temp\ipykernel_3068\2857049849.py:3: in predict_model
#     return model.predict(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# C:\Users\Shahram\AppData\Local\Temp\ipykernel_3068\1005664956.py:5: in wrap
#     f(*args, **kwargs)
# E   RecursionError: maximum recursion depth exceeded
# !!! Recursion detected (same locals & position)
# -------------------------------------- Captured stdout call ---------------------------------------
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# Before
# ===================================== short test summary info =====================================
# FAILED t_76afb62dd1e94f36929c977f3791daa6.py::test_typical_case - RecursionError: maximum recursion depth exceeded
# FAILED t_76afb62dd1e94f36929c977f3791daa6.py::test_error_handling_missing_values - RecursionError: maximum recursion depth exceeded
# FAILED t_76afb62dd1e94f36929c977f3791daa6.py::test_edge_case_extreme_values - RecursionError: maximum recursion depth exceeded
# ======================================== 3 failed in 0.19s ========================================
# <ExitCode.TESTS_FAILED: 1>
